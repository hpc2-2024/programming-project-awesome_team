# %%
import os
NUM_THREADS = "8"
os.environ["OMP_NUM_THREADS"] = NUM_THREADS 
os.environ["OPENBLAS_NUM_THREADS"] = NUM_THREADS
os.environ["MKL_NUM_THREADS"] = NUM_THREADS
os.environ["VECLIB_MAXIMUM_THREADS"] = NUM_THREADS
os.environ["NUMEXPR_NUM_THREADS"] = NUM_THREADS

# %%
import subprocess
import re
import numpy as np
import matplotlib.pyplot as plt

# %%
def compile_run_program(compile_cmd, run_cmd):
    program_output = ""
    compile_process = subprocess.run(compile_cmd, capture_output=True, text=True)

    if compile_process.returncode == 0:        
        # Run the compiled program
        run_process = subprocess.run(run_cmd, capture_output=True, text=True)
        program_output = run_process.stdout
    else:
        print("Compilation failed.")
        print("Compiler output:")
        print(compile_process.stderr)
    return program_output

# %%
# Define relative paths
SRC_DIR = ".."
PROGRAM = "mg.c"
OUTPUT = "mg.exe"
IMG_OUTPUT = "../images"
IMG = "mg_cycle_time.png"

DIMENSION="2"
LEVELS="4"
SMOOTH_STEPS="2"
SMOOTHER="0"

FLAG_TIME="-time"
FLAG_AVG_TIME="-avg_time"
FLAG_W_CYCLE="-wcycle"
FLAG_F_CYCLE="-fcycle"
FLAG_STENCIL9="-stencil9"

pattern = re.compile(r"(\d+\.\d+) seconds")

compile_command = ["gcc", "-g2", "-lm", "-fopenmp", "-I../src_mg", 
                   os.path.join(SRC_DIR, PROGRAM), "-o", os.path.join(SRC_DIR, OUTPUT)]

GRIDSIZES = [str(2**x - 1) for x in range(3,9)] 
times = np.zeros((3,len(GRIDSIZES)))

for i, GRIDSIZE in enumerate(GRIDSIZES):
    run_command = [os.path.join(SRC_DIR, OUTPUT), DIMENSION, GRIDSIZE, LEVELS, SMOOTH_STEPS, SMOOTHER, FLAG_AVG_TIME]
    program_output = compile_run_program(compile_command, run_command)
    # print(program_output)
    match = re.search(pattern, program_output)

    if match:
        times[0,i] = float(match.group(1))
    else:
        times[0,i] = -1.0

for i, GRIDSIZE in enumerate(GRIDSIZES):
    run_command = [os.path.join(SRC_DIR, OUTPUT), DIMENSION, GRIDSIZE, LEVELS, SMOOTH_STEPS, SMOOTHER, FLAG_F_CYCLE, FLAG_AVG_TIME]
    program_output = compile_run_program(compile_command, run_command)
    match = re.search(pattern, program_output)

    if match:
        times[1,i] = float(match.group(1))
    else:
        times[1,i] = -1.0

for i, GRIDSIZE in enumerate(GRIDSIZES):
    run_command = [os.path.join(SRC_DIR, OUTPUT), DIMENSION, GRIDSIZE, LEVELS, SMOOTH_STEPS, SMOOTHER, FLAG_W_CYCLE, FLAG_AVG_TIME]
    program_output = compile_run_program(compile_command, run_command)
    match = re.search(pattern, program_output)

    if match:
        times[2,i] = float(match.group(1))
    else:
        times[2,i] = -1.0

plt.plot([int(i) for i in GRIDSIZES], times[0,:], label='V-Cycle', marker='o')
plt.plot([int(i) for i in GRIDSIZES], times[1,:], label='F-Cycle', marker='o')
plt.plot([int(i) for i in GRIDSIZES], times[2,:], label='W-Cycle', marker='o')

plt.xlabel('Grid Size (# of points)')
plt.ylabel('Time (s)')
plt.title('Time till Convergence (V- vs. F- vs. W-Cycle)')
plt.legend()

os.makedirs(IMG_OUTPUT, exist_ok=True)
output_file = os.path.join(IMG_OUTPUT, IMG)
plt.savefig(output_file)

plt.show()
